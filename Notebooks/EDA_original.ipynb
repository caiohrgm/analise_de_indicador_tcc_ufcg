# %%
import utils
import warnings
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

global companies_set 

warnings.filterwarnings('ignore')

# %% [markdown]
# # 1 - Pré-Processamento

# %%
path = r"D:\Documentos_D\UFCG\2021.2e\TCC\Project\analise-de-indicador-tcc-ufcg\Data\indicadores_Siteware.csv"
companies_set = utils.prepare_datasets(path)
# Out:
# Informações básicas do conjunto de indicadores:
# Empresas:  ['BC' 'BI' 'BR' 'BT']
# Canais:  ['NaN' 'ME' 'EE' 'MI']
# Mercado:  ['NaN' 'R1' 'R2' 'R3' 'R4' 'R5' 'R6']
#
# Obs: Os canais e mercados que são 'NaN' serão desconsiderados.
#                             Qtd
# Canal_Distribuicao Mercado
# ME                 NaN      121
#                    R1       193
# NaN                NaN      121
#                             Qtd
# Canal_Distribuicao Mercado
# ME                 NaN      121
#                    R2       193
#                    R3       193
#                    R5        65
# NaN                NaN      121
#                             Qtd
# Canal_Distribuicao Mercado
# EE                 NaN      121
#                    R1       144
#                    R2       193
#                    R3       145
#                    R4       131
#                    R5       168
# ME                 NaN      121
# MI                 R6       169
# ...

# %% [markdown]
# # 2 - Análise Exploratória dos Dados

# %% [markdown]
# ## 2.1 - Análise dos mercados (independente da empresa)

# %%
df = pd.DataFrame()


for tpl in companies_set:
    temp_df = tpl[1].reset_index().drop(['index'],axis=1).sort_values(by='Mercado')
    temp_df = temp_df[((temp_df.Empresa != "NaN") & (temp_df.Mercado != "NaN"))]

    df = df.append(temp_df)

df = df.sort_values(by='Volume_Venda').reset_index().drop(['index'],axis=1)
# display(df)
# df = df.drop_duplicates('Data',keep='last').sort_values(by='Data').reset_index().drop(['index'],axis=1)

markets = ['R1', 'R2', 'R3', 'R4', 'R5', 'R6',]
for market in markets:
    market_df = df[(df.Mercado == market)].sort_values(by='Volume_Venda')
    display(market_df.sort_values(by="Data").head(12))
    # market_df = market_df.drop_duplicates('Data',keep='last').sort_values(by='Data').reset_index().drop(['index'],axis=1)



    display(market_df.sort_values(by="Data"))
# Out:
#      Empresa Canal_Distribuicao Mercado Volume_Venda                     Data
# 394       BC                 ME      R1          0.0  2012-01-01 00:00:00.000
# 519       BC                 ME      R1        200.0  2012-01-01 00:00:00.000
# 295       BR                 EE      R1          0.0  2012-01-01 00:00:00.000
# 1057      BC                 ME      R1       9298.0  2012-01-01 00:00:00.000
# 302       BR                 EE      R1          0.0  2012-01-01 00:00:00.000
# 1066      BC                 ME      R1       9498.0  2012-01-01 00:00:00.000
# 577       BC                 ME      R1        600.0  2012-02-01 00:00:00.000
# 1217      BR                 EE      R1      13000.0  2012-02-01 00:00:00.000
# 1220      BR                 EE      R1      13000.0  2012-02-01 00:00:00.000
# 393       BC                 ME      R1          0.0  2012-02-01 00:00:00.000
# 1035      BC                 ME      R1       8996.0  2012-02-01 00:00:00.000
# ...
